# %%
# 데이터 분석 패키지
import numpy as np
import pandas as pd

# %%
# 모든 컬럼을 출력하도록 설정
pd.set_option('display.max_columns', None)  # None으로 설정하면 모든 컬럼 출력
# 모든 행을 출력하도록 설정
pd.set_option('display.max_rows', 50)  # None으로 설정하면 모든 행 출력

# %%
df_stocks = pd.read_csv('stocks.csv')

# %%
df_stocks.head(1)
# Out:
#      Code  Name Market Dept  Close  ChangeCode  Changes  ChagesRatio   Open  \
# 0  005930  삼성전자  KOSPI  NaN  54200           1      100         0.18  53500
#
#     High    Low    Volume        Amount           Marcap      Stocks MarketId  \
# 0  54600  53300  12626235  680246198500  323562214210000  5969782550      STK
#
#            Sector                                           Industry  \
# 0  통신 및 방송 장비 제조업  통신 및 방송 장비 제조(무선) 제품, 반도체 제조(메모리) 제품, 전자부품 제조(...
#
#   ListingDate SettleMonth Representative                    HomePage Region
# 0  1975-06-11         12월            한종희  http://www.samsung.com/sec    경기도

# %%
df_stocks.index[df_stocks['ChagesRatio'] == 30]
# Out:
# Index([1232, 2018], dtype='int64')

# %% [markdown]
# #### 행추출 방법

# %%
# 행추출 방법
# 1. [] : 대괄호 접근
# df_stocks[df_stocks['ChagesRatio'] == 30]
# 2. loc : 인덱스명
# df_stocks.loc[df_stocks['ChagesRatio'] == 30]
# 3. iloc : 인덱스번호
indices = df_stocks.index[df_stocks['ChagesRatio'] == 30]
df_stocks.iloc[indices]
# 4. query
# df_stocks.query('ChagesRatio == 30')
# Out:
#         Code    Name  Market   Dept  Close  ChangeCode  Changes  ChagesRatio  \
# 1232  050960  수산아이앤티  KOSDAQ  벤처기업부  15860           4     3660         30.0
# 2018  121850     코이즈  KOSDAQ  벤처기업부   1495           4      345         30.0
#
#        Open   High    Low   Volume       Amount        Marcap    Stocks  \
# 1232  11000  15860  10640   950437  13732652520  107070860000   6751000
# 2018   1140   1495   1067  4923010   6886680301   45768191625  30614175
#
#      MarketId          Sector              Industry ListingDate SettleMonth  \
# 1232      KSQ  소프트웨어 개발 및 공급업  공유단말접속관리서비스, 보안솔루션 등  2016-10-11         12월
# 2018      KSQ      플라스틱제품 제조업        보호필름, 도광판, 백코팅  2012-09-27         12월
#
#      Representative                    HomePage Region
# 1232            정은아  http://www.soosanint.co.kr  서울특별시
# 2018            조재형       http://www.koyj.co.kr   충청북도

# %% [markdown]
# #### 행을 추출한뒤 열을 추출방법

# %%
# 1. [] : 대괄호 접근
# df_stocks[df_stocks['ChagesRatio'] == 30][['Name','Sector']]
# 2. loc : 인덱스명
# df_stocks.loc[df_stocks['ChagesRatio'] == 30][['Name','Sector']]
# df_stocks.loc[df_stocks['ChagesRatio'] == 30,['Name','Sector']]
# 3. iloc : 인덱스번호
# indices = df_stocks.index[df_stocks['ChagesRatio'] == 30]
# df_stocks.iloc[indices]
# df_stocks.iloc[df_stocks.index[df_stocks['ChagesRatio'] == 30]][['Name','Sector']]
# df_stocks.iloc[df_stocks.index[df_stocks['ChagesRatio'] == 30], [1,16]]
# 4. query
df_stocks.query('ChagesRatio == 30')[['Name','Sector']]
# Out:
#         Name          Sector
# 1232  수산아이앤티  소프트웨어 개발 및 공급업
# 2018     코이즈      플라스틱제품 제조업

# %%
df_stocks.describe()
# Out:
#               Close   ChangeCode        Changes  ChagesRatio          Open  \
# count  2.856000e+03  2856.000000    2856.000000  2856.000000  2.856000e+03
# mean   1.727781e+04     1.741597    -252.238095    -1.340434  1.735008e+04
# std    5.555771e+04     0.618823    3615.763860     3.899823  5.960333e+04
# min    3.000000e+00     0.000000 -187000.000000   -29.930000  0.000000e+00
# 25%    2.078750e+03     1.000000    -200.000000    -3.060000  2.000000e+03
# 50%    4.800000e+03     2.000000     -50.000000    -1.280000  4.677500e+03
# 75%    1.277500e+04     2.000000       0.000000     0.000000  1.266750e+04
# max    1.813000e+06     5.000000    8800.000000    30.000000  2.124000e+06
#
#                High           Low        Volume        Amount        Marcap  \
# count  2.856000e+03  2.856000e+03  2.856000e+03  2.856000e+03  2.856000e+03
# mean   1.772746e+04  1.658957e+04  5.309359e+05  6.083786e+09  8.130226e+11
# std    6.369783e+04  5.402176e+04  2.191040e+06  3.565241e+10  7.277021e+12
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  5.180000e+07
# 25%    2.015000e+03  1.970750e+03  2.497900e+04  1.015650e+08  4.137168e+10
# 50%    4.797500e+03  4.445000e+03  9.306500e+04  4.239842e+08  8.954548e+10
# 75%    1.288250e+04  1.211000e+04  2.738850e+05  1.842106e+09  2.277213e+11
# max    2.407000e+06  1.736000e+06  3.784488e+07  1.228937e+12  3.229652e+14
#
#              Stocks
# count  2.856000e+03
# mean   4.186027e+07
# std    1.327892e+08
# min    2.000000e+05
# 25%    1.017354e+07
# 50%    1.977295e+07
# 75%    4.189457e+07
# max    5.969783e+09

# %%
# 전일 대비 상승률 상위 30위 종목
top_30_increse_indices =df_stocks.sort_values('ChagesRatio',ascending=False).head(30).index
df_top_30_increse = df_stocks.iloc[top_30_increse_indices]
df_top_30_increse
# Out:
#         Code     Name  Market     Dept  Close  ChangeCode  Changes  \
# 2085  139670    키네마스터  KOSDAQ    중견기업부   3120           4      720
# 2608  030350   드래곤플라이  KOSDAQ    중견기업부   1244           4      287
# 1856  015020     이스타코   KOSPI      NaN   1301           4      300
# 1371  383930   디티앤씨알오  KOSDAQ    중견기업부   7480           4     1720
# 1552  065500   오리엔트정공  KOSDAQ    중견기업부   2480           4      569
# 492   025950     동신건설  KOSDAQ    우량기업부  44050           1     8800
# 1566  020710     시공테크  KOSDAQ    우량기업부   3880           1      715
# 2563  004105    태양금속우   KOSPI      NaN   5980           1     1070
# 982   013360     일성건설   KOSPI      NaN   2785           1      485
# 670   045660      에이텍  KOSDAQ    우량기업부  29500           1     5100
# 2255  121850      코이즈  KOSDAQ    벤처기업부   1150           1      195
# 1623  045340    토탈소프트  KOSDAQ    벤처기업부   8600           1     1440
# 2358  065770       CS  KOSDAQ    벤처기업부   1549           1      256
# 1508  050960   수산아이앤티  KOSDAQ    벤처기업부  12200           1     1890
# 1186  224110  에이텍모빌리티  KOSDAQ    중견기업부  21800           1     3310
# 1412  007720   대명소노시즌  KOSDAQ    중견기업부    906           1      133
# 1600  052220     iMBC  KOSDAQ    중견기업부   3285           1      460
# 2528                                        알미늄괴  1993-12-07         12월
#
#          Representative                       HomePage   Region
# 2085     홍기태, 송광은(공동대표)  http://www.kinemastercorp.com    서울특별시
# 2608                조 철   http://www.dragonflygame.com    서울특별시
# 1856      김승제,김동현(각자대표)      http://www.e-starco.co.kr    서울특별시
# 1371                박채규          http://www.dtncro.com      경기도
# 1552           장재진, 박영동      http://www.orientpi.co.kr     경상북도
# 492             김근한,김동한         http://www.dongsin.biz     경상북도
# 1566                김승태    http://www.sigongtech.co.kr      경기도
# 2563                NaN                            NaN      NaN
# 982                 유필상   http://www.ilsungconst.co.kr      경기도
# 670   신승영, 이상훈(각자 대표이사)             http://www.atec.kr      경기도
# 2255                조재형          http://www.koyj.co.kr     충청북도
# 1623                최장수           http://www.tsb.co.kr    부산광역시
# 2358                최규훈   http://www.cs-holdings.co.kr      경기도
# 1508                정은아     http://www.soosanint.co.kr    서울특별시
# 1186   신승영, 최성용(각자대표이사)    http://www.atecmobility.com      경기도
# 1412                권광수          http://sonoseason.com  강원특별자치도
# 1600                이선태           http://corp.imbc.com    서울특별시
# 472     임창욱, 최성수 각자대표이사                            NaN    서울특별시
# 1851                최준호   http://www.hyungji-elite.com    인천광역시
# 2822           조호현, 이병진       http://www.panggame.com/    서울특별시
# 1088                장수현       http://www.opasnet.co.kr    서울특별시
# 1183           차중석, 차정헌          http://www.jchyun.com    서울특별시
# 2819                박인철     http://www.flexpower.co.kr    서울특별시
# 1704                손수근        http://www.inthef.co.kr    서울특별시
# 1461                박영건             http://ggumbi.com/      경기도
# 2245                주재현     http://www.nanobrick.co.kr      경기도
# 2078                김태인           http://www.cas.co.kr      경기도
# 2548                NaN                            NaN      NaN
# 553                 조정일               http://konai.com    서울특별시
# 2528  이태용, 최재훈 (각자대표이사)        http://www.samboind.com     경상남도

# %%
# 전일 대비 상승률 하위 30위 종목
bottom_30_increse_indices =df_stocks.sort_values('ChagesRatio',ascending=True).head(30).index
df_bottom_30_increse = df_stocks.iloc[bottom_30_increse_indices]
df_bottom_30_increse
# Out:
#         Code         Name  Market             Dept  Close  ChangeCode  \
# 1205  294090        이오플로우  KOSDAQ          기술성장기업부   3770           5
# 2855  419700     이브이파킹서비스   KONEX            일반기업부      3           2
# 2641  031860       에스유홀딩스  KOSDAQ  투자주의환기종목(소속부없음)   1020           2
# 1800  006050        국영지앤엠  KOSDAQ            중견기업부   1718           2
# 833   321820    아티스트유나이티드  KOSDAQ          기술성장기업부  13590           2
# 2448  025560         미래산업   KOSPI              NaN    822           2
# 1685  024740         한일단조  KOSDAQ            중견기업부   2100           2
# 2828  002995        금호건설우   KOSPI              NaN  12900           2
# 2784  116100         태양기계   KONEX            일반기업부   1226           5
# 2806  092590         럭스피아   KONEX            일반기업부    807           5
# 2808  448780      마이크로엔엑스   KONEX            일반기업부   2025           5
# 2674  178600        대동고려삼   KONEX            일반기업부   2975           5
# 2638  223220         로지스몬   KONEX            일반기업부    340           5
# 2409  354390     바스칸바이오제약   KONEX            일반기업부   3920           2
# 1541  465480         인스피언  KOSDAQ            벤처기업부   7830           2
# 1584               AMCs 모니터링 시스템, 공정 프로세스 모니터링 시스템, TMS  2020-10-30
# 663                             VFX, 뉴미디어 등 특수영상 컨텐츠 제작  2018-12-20
# 2825                                                NaN         NaN
# 1889                    방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)  2024-11-19
# 1509                                      OLED 발광층 소재 등  2024-10-22
# 1714                                     생체현미경, CRO 서비스  2024-08-06
# 2235                   LSMB(Laser Micro Bonding System)  2024-06-11
# 1308                                    신속항균제검사 장비 및 키트  2020-12-09
# 468                                           바이오시밀러 제조  2021-03-11
#
#      SettleMonth    Representative                               HomePage  \
# 1205         12월               김재진                  http://www.eoflow.com
# 2855         12월               김정수                     http://evps.co.kr/
# 2641         12월        이상욱 (단독대표)                 http://su-holdings.com
# 1800         12월               최재원                 http://www.kukyong.com
# 833          12월               이태성             http://www.widerplanet.com
# 2448         12월               이창재                 http://www.mirae.co.kr
# 1685         12월               박정영                  http://www.hifg.co.kr
# 2828         NaN               NaN                                    NaN
# 2784         12월               박창엽                http://www.sun-mc.co.kr
# 2806         12월               성석종               http://www.luxpialed.com
# 2808         12월           이종건/정재경               http://www.micronx.co.kr
# 2674         06월             최 성 근               http://www.ddkorea.co.kr
# 2638         12월               이석준                 http://ipmonster.co.kr
# 2409         12월               이법표              http://www.baskhanbio.com
# 1541         12월               최정규               http://www.inspien.co.kr
# 1035         12월  각자 대표이사 이준우, 최성원               http://www.aurostech.com
# 559          12월   김재영, 남정선 (각자대표)                  http://www.jetema.com
# 1848         12월               김태규  http://www.vigencell.com/kr/index.asp
# 916          12월           김욱, 강종익           http://www.dexterstudios.com
# 727          12월               백준현                       http://zaram.com
# 624          12월               최성준                  http://www.ygplus.com
# 1584         12월  유승교,박현열(각자 대표이사)              http://www.withtech.co.kr
# 663          12월               조성완             http://www.wswgstudios.com
# 2825         NaN               NaN                                    NaN
# 1889         12월               한기우           http://www.rf-systems.co.kr/
# 1509         12월               이상조                 http://www.hanchem.net
# 1714         12월               김필한                http://www.ivimtech.com
# 2235         12월               남기중               http://www.nexview.co.kr
# 1308         12월               권성훈            http://www.quantamatrix.com
# 468          06월               현덕훈       http://www.prestigebiologics.com
#
#        Region
# 1205      경기도
# 2855    서울특별시
# 2641    서울특별시
# 1800    서울특별시
# 833     서울특별시
# 2448     충청남도
# 1685     충청북도
# 2828      NaN
# 2784      경기도
# 2806      경기도
# 2808    대구광역시
# 2674     충청남도
# 2638    서울특별시
# 2409      경기도
# 1541    서울특별시
# 1035      경기도
# 559   강원특별자치도
# 1848    서울특별시
# 916     서울특별시
# 727       경기도
# 624     서울특별시
# 1584    대전광역시
# 663     서울특별시
# 2825      NaN
# 1889      경기도
# 1509    대전광역시
# 1714    대전광역시
# 2235      경기도
# 1308    서울특별시
# 468      충청북도

# %%
# 전일 대비 상승률 상위 30위 종목
# 업종
# df_top_30_increse['Sector'].value_counts()
df_bottom_30_increse['Sector'].value_counts()
# Out:
# Sector
# 의료용 기기 제조업                               3
# 자동차 신품 부품 제조업                            2
# 영화, 비디오물, 방송프로그램 제작 및 배급업                2
# 의약품 제조업                                  2
# 반도체 제조업                                  2
# 사진장비 및 광학기기 제조업                          2
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외    2
# 소프트웨어 개발 및 공급업                           2
# 기타 식품 제조업                                1
# 기계장비 및 관련 물품 도매업                         1
# 유리 및 유리제품 제조업                            1
# 특수 목적용 기계 제조업                            1
# 의료용품 및 기타 의약 관련제품 제조업                    1
# 자연과학 및 공학 연구개발업                          1
# 상품 종합 도매업                                1
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업         1
# 기타 금속 가공제품 제조업                           1
# 기초 화학물질 제조업                              1
# 기타 운송관련 서비스업                             1
# Name: count, dtype: int64

# %%
df_stocks.index
# Out:
# RangeIndex(start=0, stop=2856, step=1)

# %%
df_stocks.groupby('Sector')[['Marcap']].idxmax()
# Out:
#                      Marcap
# Sector
# 1차 비철금속 제조업               7
# 1차 철강 제조업                13
# 가구 제조업                  413
# 가전제품 및 정보통신장비 소매업       868
# 가정용 기기 제조업              140
# ...                     ...
# 항공기,우주선 및 부품 제조업         30
# 해상 운송업                   25
# 해체, 선별 및 원료 재생업        1927
# 화학섬유 제조업                248
# 회사 본부 및 경영 컨설팅 서비스업     294
#
# [160 rows x 1 columns]

# %%
dir(df_stocks.groupby('Sector')['Marcap'])
# Out:
# ['_SeriesGroupBy__examples_series_doc',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_agg_py_fallback',
#  '_aggregate_multiple_funcs',
#  '_aggregate_named',
#  '_aggregate_with_numba',
#  '_apply_filter',
#  '_ascending_count',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_general',
#  '_cython_transform',
#  '_deprecate_axis',
#  '_descending_count',
#  '_dir_additions',
#  '_dir_deletions',
#  '_fill',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_gotitem',
#  '_grouper',
#  '_hidden_attrs',
#  '_idxmax_idxmin',
#  '_infer_selection',
#  '_insert_inaxis_grouper',
#  '_internal_names',
#  '_internal_names_set',
#  '_make_mask_from_int',
#  '_make_mask_from_list',
#  '_make_mask_from_positional_indexer',
#  '_make_mask_from_slice',
#  '_make_mask_from_tuple',
#  '_mask_selected_obj',
#  '_maybe_transpose_result',
#  '_nth',
#  '_numba_agg_general',
#  '_numba_prep',
#  '_obj_1d_constructor',
#  '_obj_with_exclusions',
#  '_op_via_apply',
#  '_positional_selector',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_reindex_output',
#  '_reset_cache',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_set_result_index_ordered',
#  '_transform',
#  '_transform_general',
#  '_transform_with_numba',
#  '_value_counts',
#  '_wrap_agged_manager',
#  '_wrap_aggregated_output',
#  '_wrap_applied_output',
#  '_wrap_idxmax_idxmin',
#  '_wrap_transform_fast_result',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'bfill',
#  'corr',
#  'count',
#  'cov',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'dtype',
#  'ewm',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'get_group',
#  'groups',
#  'head',
#  'hist',
#  'idxmax',
#  'idxmin',
#  'indices',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'last',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'ndim',
#  'ngroup',
#  'ngroups',
#  'nlargest',
#  'nsmallest',
#  'nth',
#  'nunique',
#  'ohlc',
#  'pct_change',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'rank',
#  'resample',
#  'rolling',
#  'sample',
#  'sem',
#  'shift',
#  'size',
#  'skew',
#  'std',
#  'sum',
#  'tail',
#  'take',
#  'transform',
#  'unique',
#  'value_counts',
#  'var']

# %%
df_stocks.groupby('Sector')['Marcap'].sum()
# Out:
# Sector
# 1차 비철금속 제조업            42025679933262
# 1차 철강 제조업              36062504736190
# 가구 제조업                  1579352329179
# 가전제품 및 정보통신장비 소매업        173044528960
# 가정용 기기 제조업              3750559291419
#                             ...
# 항공기,우주선 및 부품 제조업       20223759888903
# 해상 운송업                 18821548038885
# 해체, 선별 및 원료 재생업           52393434311
# 화학섬유 제조업                3602587510624
# 회사 본부 및 경영 컨설팅 서비스업     3497612924040
# Name: Marcap, Length: 160, dtype: int64

# %%
df_stocks.groupby('Sector')['Marcap'].sum().reset_index()
# Out:
#                   Sector          Marcap
# 0            1차 비철금속 제조업  42025679933262
# 1              1차 철강 제조업  36062504736190
# 2                 가구 제조업   1579352329179
# 3      가전제품 및 정보통신장비 소매업    173044528960
# 4             가정용 기기 제조업   3750559291419
# ..                   ...             ...
# 155     항공기,우주선 및 부품 제조업  20223759888903
# 156               해상 운송업  18821548038885
# 157      해체, 선별 및 원료 재생업     52393434311
# 158             화학섬유 제조업   3602587510624
# 159  회사 본부 및 경영 컨설팅 서비스업   3497612924040
#
# [160 rows x 2 columns]

# %%
df_stocks.groupby('Sector')['Marcap'].idxmax()
# Out:
# Sector
# 1차 비철금속 제조업               7
# 1차 철강 제조업                13
# 가구 제조업                  413
# 가전제품 및 정보통신장비 소매업       868
# 가정용 기기 제조업              140
#                        ...
# 항공기,우주선 및 부품 제조업         30
# 해상 운송업                   25
# 해체, 선별 및 원료 재생업        1927
# 화학섬유 제조업                248
# 회사 본부 및 경영 컨설팅 서비스업     294
# Name: Marcap, Length: 160, dtype: int64

# %%
# 산업별 시가총액 상위목록
print(df_stocks.columns)

# 산업별 시가 총액 합계 계산
grouped = df_stocks.groupby('Sector')['Marcap'].sum().reset_index()

# 각 산업별로 시가총액이 가장 높은 기업 찾기
top_industries = df_stocks.loc[df_stocks.groupby('Sector')['Marcap'].idxmax()]

top_industries
# Out:
# Index(['Code', 'Name', 'Market', 'Dept', 'Close', 'ChangeCode', 'Changes',
#        'ChagesRatio', 'Open', 'High', 'Low', 'Volume', 'Amount', 'Marcap',
#        'Stocks', 'MarketId', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')
#         Code       Name         Market             Dept    Close  ChangeCode  \
# 7     010130       고려아연          KOSPI              NaN  1813000           2
# 13    005490   POSCO홀딩스          KOSPI              NaN   265500           2
# 413   013890        지누스          KOSPI              NaN    23100           1
# 868   071840     롯데하이마트          KOSPI              NaN     7330           2
# 140   065350     신성델타테크         KOSDAQ            우량기업부    74600           1
# ...      ...        ...            ...              ...      ...         ...
# 30    012450  한화에어로스페이스          KOSPI              NaN   298000           2
# 25    011200        HMM          KOSPI              NaN    18000           2
# 1927  032860        더라미         KOSDAQ  투자주의환기종목(소속부없음)     1297           2
# 248   298020      효성티앤씨          KOSPI              NaN   218000           2
# 294   036830    솔브레인홀딩스  KOSDAQ GLOBAL            우량기업부    35550           2
#
#       Changes  ChagesRatio     Open     High      Low   Volume        Amount  \
# 7     -187000        -9.35  2124000  2407000  1736000   248705  520852009000
# 13      -1000        -0.38   266500   270500   257000   464808  122727927500
# 413      1300         5.96    22200    23800    21900   347667    8013373900
# 868      -100        -1.35     7360     7480     7090    45959     333161100
# 140       800         1.08    74100    79400    73000   634228   48251391600
# ...       ...          ...      ...      ...      ...      ...           ...
# 30     -10000        -3.25   314500   317500   286000   932726  276597954500
# 25       -210        -1.15    18220    18500    17750  1153122   20900707030
# 1927      -30        -2.26     1294     1330     1257   167150     215121823
# 248     -2500        -1.13   222500   222500   212000    25907    5624492000
# 294      -400        -1.11    36250    37550    34850   112767    4068258300
#
#               Marcap     Stocks MarketId               Sector  \
# 7     37535052079000   20703283      STK          1차 비철금속 제조업
# 13    21936772093500   82624377      STK            1차 철강 제조업
# 413     468025219200   20260832      STK               가구 제조업
# 868     173044528960   23607712      STK    가전제품 및 정보통신장비 소매업
# 140    2050302520800   27483948      KSQ           가정용 기기 제조업
# ...              ...        ...      ...                  ...
# 30    13583185978000   45581161      STK     항공기,우주선 및 부품 제조업
# 25    15858710928000  881039496      STK               해상 운송업
# 1927     52393434311   40395863      KSQ      해체, 선별 및 원료 재생업
# 248     943434676000    4327682      STK             화학섬유 제조업
# 294     745272190800   20964056      KSQ  회사 본부 및 경영 컨설팅 서비스업
#
#                             Industry ListingDate SettleMonth  \
# 7                        연,아연괴 제조,판매  1990-07-28         12월
# 13          열연코일,냉연강판,후판,선재,스테인리스 제조  1988-06-10         12월
# 413                      매트리스 및 가구제품  2019-10-30         12월
# 868               가전제품,잡화 도소매/부동산 임대  2011-06-29         12월
# 140           세탁기, 자동차, 에어컨 및 LCD 부품  2004-08-06         12월
# ...                              ...         ...         ...
# 30              항공기엔진,특수방산장비 제조/정비사업  1987-05-27         12월
# 25     정기,부정기,전용선,콘테이너선,자동차선,LNG선 해운  1995-10-05         12월
# 1927                       화장품, 철스크랩  1997-07-04         12월
# 248   섬유, 산업자재, 화학, 중공업, 건설, 무역,금융 등  2018-07-13         12월
# 294          반도체,디스플레이,2차전지 공정용 화학제품  2000-01-18         12월
#
#                 Representative                            HomePage Region
# 7                     박기덕, 정태웅          http://www.koreazinc.co.kr  서울특별시
# 13    대표이사 회장 장인화, 대표이사 사장 정기섭            http://www.posco-inc.com   경상북도
# 413                        윤종원              http://www.zinus.co.kr    경기도
# 868                        남창희         http://company.himart.co.kr  서울특별시
# 140           구본상·이동한(각자 대표이사)            http://www.ssdelta.co.kr   경상남도
# ...                        ...                                 ...    ...
# 30                    손재일, 김동관   http://www.hanwhaaerospace.co.kr/   경상남도
# 25                         김경배                http://www.hmm21.com  서울특별시
# 1927                       현병택              http://www.thelamy.com    경기도
# 248                        김치형           http://www.hyosungtnc.com  서울특별시
# 294                        정현석  http://www.soulbrainholdings.co.kr    경기도
#
# [160 rows x 23 columns]
