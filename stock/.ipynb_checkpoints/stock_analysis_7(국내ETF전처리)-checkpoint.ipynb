# %%
# 데이터 분석 패키지
import numpy as np
import pandas as pd

# %%
# 모든 컬럼을 출력하도록 설정
pd.set_option('display.max_columns', None)  # None으로 설정하면 모든 컬럼 출력
# 모든 행을 출력하도록 설정
pd.set_option('display.max_rows', 50)  # None으로 설정하면 모든 행 출력

# %%
# 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# matplotlib 한글지원 패키지
import koreanize_matplotlib

# %%
df_etfs = pd.read_csv('etf_2024-12-13.csv')

# %%
df_etfs.shape
# Out:
# (931, 12)

# %%
df_etfs.head()
# Out:
#    Symbol  Category                 Name    Price  RiseFall  Change  \
# 0  459580         6    KODEX CD금리액티브(합성)  1056890         2     290
# 1  357870         6  TIGER CD금리투자KIS(합성)    55395         2      20
# 2  360750         4       TIGER 미국S&P500    21675         2     125
# 3   69500         1            KODEX 200    32695         2     190
# 4  423160         6  KODEX KOFR금리액티브(합성)   108910         2      10
#
#    ChangeRate        NAV  EarningRate   Volume  Amount  MarCap
# 0        0.03  1056695.0       0.8465   140839  148850   93245
# 1        0.04    55390.0       0.8376    60592    3356   68918
# 2        0.58    21705.0      18.2052  2224994   48163   62576
# 3        0.58    32676.0      -3.0570  2970867   97223   55663
# 4        0.01   108900.0       0.8380    19950    2172   44454

# %%
# 거래량 기준으로 상위 10개 데이터 가져오기
df_etfs.sort_values('Volume', ascending=False).head(10)
# Out:
#      Symbol  Category               Name  Price  RiseFall  Change  ChangeRate  \
# 30   252670         3   KODEX 200선물인버스2X   2490         5     -25       -0.99
# 20   233740         3   KODEX 코스닥150레버리지   6930         2     150        2.21
# 139  251340         3  KODEX 코스닥150선물인버스   4095         5     -50       -1.21
# 12   122630         3         KODEX 레버리지  14500         2     150        1.05
# 62   114800         3          KODEX 인버스   4700         5     -25       -0.53
# 153  462330         2   KODEX 2차전지산업레버리지   1464         5     -10       -0.68
# 28   229200         1       KODEX 코스닥150  11475         2     130        1.15
# 29   148020         1           RISE 200  32930         2     175        0.53
# 3     69500         1          KODEX 200  32695         2     190        0.58
# 150  487240         2     KODEX AI전력핵심설비   9085         2      70        0.78
#
#          NAV  EarningRate    Volume  Amount  MarCap
# 30    2491.0       5.6722  48042824  119339   11334
# 20    6958.0     -10.7308  26094864  181223   17907
# 139   4114.0       2.7261  23920770   97995    2162
# 12   14556.0      -8.1600  12598127  183165   24157
# 62    4704.0       3.7321   6689448   31432    5593
# 153   1474.0     -36.1905   5877724    8632    1959
# 28   11519.0      -3.8152   4682979   53842   12209
# 29   32938.0      -3.0344   3226153  106234   11394
# 3    32676.0      -3.0570   2970867   97223   55663
# 150   9131.0      17.4592   2755149   25094    1962

# %%
# 등락율 기준으로 상위 10개 데이터 가져오기
df_etfs.sort_values('ChangeRate', ascending=False).head(10)
# Out:
#      Symbol  Category                        Name  Price  RiseFall  Change  \
# 51   457480         4              ACE 테슬라밸류체인액티브  19035         2     985
# 268  465610         4  ACE 미국빅테크TOP7 Plus레버리지(합성)  30000         2    1465
# 131  423920         4    TIGER 미국필라델피아반도체레버리지(합성)  24305         2    1115
# 350  494310         2               KODEX 반도체레버리지   7300         2     275
# 671  494340         4             ACE 글로벌AI맞춤형반도체  11595         2     435
# 569  461910         4      PLUS 미국테크TOP10레버리지(합성)  30235         2    1080
# 488  488080         3          TIGER 반도체TOP10레버리지   4375         2     145
# 915  243890         2          TIGER 200에너지화학레버리지   3395         2     110
# 341  483340         4               ACE 구글밸류체인액티브  11295         2     365
# 867  334690         5               RISE 팔라듐선물(H)   5145         2     165
#
#      ChangeRate      NAV  EarningRate   Volume  Amount  MarCap
# 51         5.46  18746.0      69.7226  1223909   23254    6967
# 268        5.13  29984.0      63.1503    44148    1318     900
# 131        4.81  24422.0      23.3117   104967    2542    2268
# 350        3.91   7338.0          NaN    33072     243     489
# 671        3.90  11635.0          NaN    14246     165      93
# 569        3.70  30434.0      63.0592     2997      90     151
# 488        3.43   4391.0     -19.6582   242405    1072     221
# 915        3.35   3419.0     -29.0497    32863     112      25
# 341        3.34  11245.0      28.6639   130181    1468     503
# 867        3.31   5138.0      -0.7969     6594      33      44

# %%
# 파생열 추가 CategoryName
df_etfs['CategoryName'] = df_etfs['Category']

# df_etfs['CategoryName'] 코드명으로 변경
# 1.국내 시장지수 2.국내 업종/테마 3.국내파생 4.해외주식 5.원자재 6.채권 7.기타
category_decode = ['국내 시장지수','국내 업종/테마','국내파생','해외주식','원자재','채권','기타']
df_etfs['CategoryName'] = df_etfs['CategoryName'].replace([ i+1 for i in range(7)],category_decode)

# %%
df_etfs.head(1)
# Out:
#    Symbol  Category               Name    Price  RiseFall  Change  ChangeRate  \
# 0  459580         6  KODEX CD금리액티브(합성)  1056890         2     290        0.03
#
#          NAV  EarningRate  Volume  Amount  MarCap CategoryName
# 0  1056695.0       0.8465  140839  148850   93245           채권

# %%
df_etfs.columns.tolist()
# Out:
# ['Symbol',
#  'Category',
#  'Name',
#  'Price',
#  'RiseFall',
#  'Change',
#  'ChangeRate',
#  'NAV',
#  'EarningRate',
#  'Volume',
#  'Amount',
#  'MarCap',
#  'CategoryName']

# %% [markdown]
# ### 파생열 추가하기

# %% [markdown]
# #### 1) 카테고리명

# %%
# 데이터 프레임의 열 위치 바꾸는 방법
# case1) 열 재배지
columns = ['Symbol', 'Category', 'CategoryName', 'Name', 'Price', 'RiseFall', 'Change', 'ChangeRate', 'NAV', 'EarningRate', 'Volume', 'Amount', 'MarCap']
df_etfs = df_etfs[columns]
# case2) insert('삽입위치','열이름','값') 메소드
# df_etfs.insert?
# df_etfs.insert(2,'CategoryName',df_etfs.pop('CategoryName'))
# case3) reindex() 메소드
# df_etfs.reindex?
# df_etfs = df_etfs.reindex(columns = columns)

# %%
df_etfs.head(1)
# Out:
#    Symbol  Category CategoryName               Name    Price  RiseFall  \
# 0  459580         6           채권  KODEX CD금리액티브(합성)  1056890         2
#
#    Change  ChangeRate        NAV  EarningRate  Volume  Amount  MarCap
# 0     290        0.03  1056695.0       0.8465  140839  148850   93245

# %% [markdown]
# #### 2) 브랜드

# %%
# df_etfs['Name'].str.split?
df_etfs['Brand'] = df_etfs['Name'].str.split(' ').map(lambda list:list[0])

# %%
df_etfs.head(1)
# Out:
#    Symbol  Category CategoryName               Name    Price  RiseFall  \
# 0  459580         6           채권  KODEX CD금리액티브(합성)  1056890         2
#
#    Change  ChangeRate        NAV  EarningRate  Volume  Amount  MarCap  Brand
# 0     290        0.03  1056695.0       0.8465  140839  148850   93245  KODEX

# %%
# 브랜드별 차지비중 보기
# df['컬럼명' ].value_counts() : 특정 컬럼의 고유값의 개수를 계산
# df['컬럼명' ].value_counts(normalize=True) : 특정 컬럼의 고유값의 개수를 계산하고 각 값의 비율을 반환
df_etfs['Brand'].value_counts(normalize=True)
# Out:
# Brand
# KODEX         0.215897
# TIGER         0.213749
# RISE          0.126745
# ACE           0.097744
# PLUS          0.069817
# HANARO        0.059076
# SOL           0.056928
# KOSEF         0.048335
# 히어로즈          0.016112
# TIMEFOLIO     0.013963
# WON           0.012889
# KoAct         0.009667
# 1Q            0.008593
# 에셋플러스         0.008593
# 파워            0.005371
# BNK           0.005371
# UNICORN       0.004296
# HK            0.004296
# 마이다스          0.003222
# FOCUS         0.003222
# KCGI          0.003222
# 마이티           0.003222
# DAISHIN343    0.002148
# VITA          0.002148
# TRUSTON       0.002148
# TREX          0.002148
# ITF           0.001074
# Name: proportion, dtype: float64

# %%
df_etfs['Brand'].value_counts(normalize=True).map(lambda x:f'{x*100:.2f}%')
# Out:
# Brand
# KODEX         21.59%
# TIGER         21.37%
# RISE          12.67%
# ACE            9.77%
# PLUS           6.98%
# HANARO         5.91%
# SOL            5.69%
# KOSEF          4.83%
# 히어로즈           1.61%
# TIMEFOLIO      1.40%
# WON            1.29%
# KoAct          0.97%
# 1Q             0.86%
# 에셋플러스          0.86%
# 파워             0.54%
# BNK            0.54%
# UNICORN        0.43%
# HK             0.43%
# 마이다스           0.32%
# FOCUS          0.32%
# KCGI           0.32%
# 마이티            0.32%
# DAISHIN343     0.21%
# VITA           0.21%
# TRUSTON        0.21%
# TREX           0.21%
# ITF            0.11%
# Name: proportion, dtype: object

# %%
df_etfs.plot?
# Out:
# Signature:      df_etfs.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x00000280276736B0>
# File:           d:\kdt_2\anaconda3\lib\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None
#     An axes of the current figure.
# subplots : bool or sequence of iterables, default False
#     Whether to group columns into subplots:
#
#     - ``False`` : No subplots will be used
#     - ``True`` : Make separate subplots for each column.
#     - sequence of iterables of column labels: Create a subplot for each
#       group of columns. For example `[('a', 'c'), ('b', 'd')]` will
#       create 2 subplots: one with columns 'a' and 'c', and one
#       with columns 'b' and 'd'. Remaining columns that aren't specified
#       will be plotted in additional subplots (one per column).
#
#       .. versionadded:: 1.5.0
#
# sharex : bool, default True if ax is None else False
#     In case ``subplots=True``, share x axis and set some x axis labels
#     to invisible; defaults to True if ax is None otherwise False if
#     an ax is passed in; Be aware, that passing in both an ax and
#     ``sharex=True`` will alter all x axis labels for all axis in a figure.
# sharey : bool, default False
#     In case ``subplots=True``, share y axis and set some y axis labels to invisible.
# layout : tuple, optional
#     (rows, columns) for the layout of subplots.
# figsize : a tuple (width, height) in inches
#     Size of a figure object.
# use_index : bool, default True
#     Use index as ticks for x axis.
# title : str or list
#     Title to use for the plot. If a string is passed, print the string
#     at the top of the figure. If a list is passed and `subplots` is
#     True, print each item in the list above the corresponding subplot.
# grid : bool, default None (matlab style default)
#     Axis grid lines.
# legend : bool or {'reverse'}
#     Place legend on axis subplots.
# style : list or dict
#     The matplotlib line style per column.
# logx : bool or 'sym', default False
#     Use log scaling or symlog scaling on x axis.
#
# logy : bool or 'sym' default False
#     Use log scaling or symlog scaling on y axis.
#
# loglog : bool or 'sym', default False
#     Use log scaling or symlog scaling on both x and y axes.
#
# xticks : sequence
#     Values to use for the xticks.
# yticks : sequence
#     Values to use for the yticks.
# xlim : 2-tuple/list
#     Set the x limits of the current axes.
# ylim : 2-tuple/list
#     Set the y limits of the current axes.
# xlabel : label, optional
#     Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the
#     x-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# ylabel : label, optional
#     Name to use for the ylabel on y-axis. Default will show no ylabel, or the
#     y-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# rot : float, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal
#     plots).
# fontsize : float, default None
#     Font size for xticks and yticks.
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that
#     name from matplotlib.
# colorbar : bool, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin'
#     plots).
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#     (center).
# table : bool, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data
#     will be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a
#     table.
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
# xerr : DataFrame, Series, array-like, dict and str
#     Equivalent to yerr.
# stacked : bool, default False in line and bar plots, and True in area plot
#     If True, create stacked plot.
# secondary_y : bool or sequence, default False
#     Whether to plot on the secondary y-axis if a list/tuple, which
#     columns to plot on secondary y-axis.
# mark_right : bool, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend.
# include_bool : bool, default is False
#     If True, boolean values can be plotted.
# backend : str, default None
#     Backend to use instead of the backend specified in the option
#     ``plotting.backend``. For instance, 'matplotlib'. Alternatively, to
#     specify the ``plotting.backend`` for the whole session, set
#     ``pd.options.plotting.backend``.
# **kwargs
#     Options to pass to matplotlib plotting method.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     If the backend is not the default matplotlib one, the return value
#     will be the object returned by the backend.
#
# Notes
# -----
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#   (center)
#
# Examples
# --------
# For Series:
#
# .. plot::
#     :context: close-figs
#
#     >>> ser = pd.Series([1, 2, 3, 3])
#     >>> plot = ser.plot(kind='hist', title="My plot")
#
# For DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
#     ...                   'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
#     ...                   index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#     >>> plot = df.plot(title="DataFrame Plot")
#
# For SeriesGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> lst = [-1, -2, -3, 1, 2, 3]
#     >>> ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
#     >>> plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot")
#
# For DataFrameGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({"col1" : [1, 2, 3, 4],
#     ...                   "col2" : ["A", "B", "A", "B"]})
#     >>> plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")
# Call docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None
#     An axes of the current figure.
# subplots : bool or sequence of iterables, default False
#     Whether to group columns into subplots:
#
#     - ``False`` : No subplots will be used
#     - ``True`` : Make separate subplots for each column.
#     - sequence of iterables of column labels: Create a subplot for each
#       group of columns. For example `[('a', 'c'), ('b', 'd')]` will
#       create 2 subplots: one with columns 'a' and 'c', and one
#       with columns 'b' and 'd'. Remaining columns that aren't specified
#       will be plotted in additional subplots (one per column).
#
#       .. versionadded:: 1.5.0
#
# sharex : bool, default True if ax is None else False
#     In case ``subplots=True``, share x axis and set some x axis labels
#     to invisible; defaults to True if ax is None otherwise False if
#     an ax is passed in; Be aware, that passing in both an ax and
#     ``sharex=True`` will alter all x axis labels for all axis in a figure.
# sharey : bool, default False
#     In case ``subplots=True``, share y axis and set some y axis labels to invisible.
# layout : tuple, optional
#     (rows, columns) for the layout of subplots.
# figsize : a tuple (width, height) in inches
#     Size of a figure object.
# use_index : bool, default True
#     Use index as ticks for x axis.
# title : str or list
#     Title to use for the plot. If a string is passed, print the string
#     at the top of the figure. If a list is passed and `subplots` is
#     True, print each item in the list above the corresponding subplot.
# grid : bool, default None (matlab style default)
#     Axis grid lines.
# legend : bool or {'reverse'}
#     Place legend on axis subplots.
# style : list or dict
#     The matplotlib line style per column.
# logx : bool or 'sym', default False
#     Use log scaling or symlog scaling on x axis.
#
# logy : bool or 'sym' default False
#     Use log scaling or symlog scaling on y axis.
#
# loglog : bool or 'sym', default False
#     Use log scaling or symlog scaling on both x and y axes.
#
# xticks : sequence
#     Values to use for the xticks.
# yticks : sequence
#     Values to use for the yticks.
# xlim : 2-tuple/list
#     Set the x limits of the current axes.
# ylim : 2-tuple/list
#     Set the y limits of the current axes.
# xlabel : label, optional
#     Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the
#     x-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# ylabel : label, optional
#     Name to use for the ylabel on y-axis. Default will show no ylabel, or the
#     y-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# rot : float, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal
#     plots).
# fontsize : float, default None
#     Font size for xticks and yticks.
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that
#     name from matplotlib.
# colorbar : bool, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin'
#     plots).
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#     (center).
# table : bool, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data
#     will be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a
#     table.
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
# xerr : DataFrame, Series, array-like, dict and str
#     Equivalent to yerr.
# stacked : bool, default False in line and bar plots, and True in area plot
#     If True, create stacked plot.
# secondary_y : bool or sequence, default False
#     Whether to plot on the secondary y-axis if a list/tuple, which
#     columns to plot on secondary y-axis.
# mark_right : bool, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend.
# include_bool : bool, default is False
#     If True, boolean values can be plotted.
# backend : str, default None
#     Backend to use instead of the backend specified in the option
#     ``plotting.backend``. For instance, 'matplotlib'. Alternatively, to
#     specify the ``plotting.backend`` for the whole session, set
#     ``pd.options.plotting.backend``.
# **kwargs
#     Options to pass to matplotlib plotting method.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     If the backend is not the default matplotlib one, the return value
#     will be the object returned by the backend.
#
# Notes
# -----
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#   (center)
#
# Examples
# --------
# For Series:
#
# .. plot::
#     :context: close-figs
#
#     >>> ser = pd.Series([1, 2, 3, 3])
#     >>> plot = ser.plot(kind='hist', title="My plot")
#
# For DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
#     ...                   'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
#     ...                   index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#     >>> plot = df.plot(title="DataFrame Plot")
#
# For SeriesGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> lst = [-1, -2, -3, 1, 2, 3]
#     >>> ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
#     >>> plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot")
#
# For DataFrameGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({"col1" : [1, 2, 3, 4],
#     ...                   "col2" : ["A", "B", "A", "B"]})
#     >>> plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")

# %%
df_etfs['Brand'].value_counts(normalize=True).sort_values(ascending=False).head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('브랜드 비중')
# Out:
# Text(0.5, 1.0, '브랜드 비중')

# %% [markdown]
# #### 인버스 비중

# %%
# 인버스 상품 가져오기
df_etfs[df_etfs['Name'].str.contains('인버스')].head(3)
# Out:
#      Symbol  Category CategoryName               Name  Price  RiseFall  \
# 30   252670         3         국내파생   KODEX 200선물인버스2X   2490         5
# 62   114800         3         국내파생          KODEX 인버스   4700         5
# 139  251340         3         국내파생  KODEX 코스닥150선물인버스   4095         5
#
#      Change  ChangeRate     NAV  EarningRate    Volume  Amount  MarCap  Brand
# 30      -25       -0.99  2491.0       5.6722  48042824  119339   11334  KODEX
# 62      -25       -0.53  4704.0       3.7321   6689448   31432    5593  KODEX
# 139     -50       -1.21  4114.0       2.7261  23920770   97995    2162  KODEX

# %%
# 인버스상품과 아닌 상품의 비율구하기
df_etfs['인버스'] = df_etfs['Name'].str.contains('인버스')
df_etfs['인버스'].value_counts(normalize=True)*100
# Out:
# 인버스
# False    95.273899
# True      4.726101
# Name: proportion, dtype: float64

# %%
# 레버리지 상품과 아닌 상품의 비율구하기
df_etfs['레버리지'] = df_etfs['Name'].str.contains('레버리지')
df_etfs['레버리지'].value_counts(normalize=True)*100
# Out:
# 레버리지
# False    94.844253
# True      5.155747
# Name: proportion, dtype: float64

# %%
# 헤지 상품과 아닌 상품의 비율구하기
df_etfs['헤지'] = df_etfs['Name'].str.endswith('(H)')
df_etfs['헤지'].value_counts(normalize=True)*100
# Out:
# 헤지
# False    93.233083
# True      6.766917
# Name: proportion, dtype: float64

# %%
df_etfs.head(2)
# Out:
#    Symbol  Category CategoryName                 Name    Price  RiseFall  \
# 0  459580         6           채권    KODEX CD금리액티브(합성)  1056890         2
# 1  357870         6           채권  TIGER CD금리투자KIS(합성)    55395         2
#
#    Change  ChangeRate        NAV  EarningRate  Volume  Amount  MarCap  Brand  \
# 0     290        0.03  1056695.0       0.8465  140839  148850   93245  KODEX
# 1      20        0.04    55390.0       0.8376   60592    3356   68918  TIGER
#
#      인버스   레버리지     헤지
# 0  False  False  False
# 1  False  False  False

# %%
df_etfs[df_etfs['레버리지']]
# Out:
#      Symbol  Category CategoryName                        Name   Price  \
# 12   122630         3         국내파생                  KODEX 레버리지   14500
# 20   233740         3         국내파생            KODEX 코스닥150레버리지    6930
# 131  423920         4         해외주식    TIGER 미국필라델피아반도체레버리지(합성)   24305
# 140  409820         4         해외주식    KODEX 미국나스닥100레버리지(합성 H)   12985
# 153  462330         2     국내 업종/테마            KODEX 2차전지산업레버리지    1464
# 223  418660         4         해외주식      TIGER 미국나스닥100레버리지(합성)   27120
# 248  204480         4         해외주식     TIGER 차이나CSI300레버리지(합성)   19870
# 268  465610         4         해외주식  ACE 미국빅테크TOP7 Plus레버리지(합성)   30000
# 279  452250         6           채권     ACE 미국30년국채선물레버리지(합성 H)    6220
# 290  412570         2     국내 업종/테마         TIGER 2차전지TOP10레버리지    1574
# 291  267770         3         국내파생             TIGER 200선물레버리지   11085
# 299  225040         4         해외주식    TIGER 미국S&P500레버리지(합성 H)   48820
# 303  236350         4         해외주식       TIGER 인도니프티50레버리지(합성)   46450
# 304  278240         3         국내파생           RISE 코스닥150선물레버리지    7820
# 322  204450         4         해외주식           KODEX 차이나H레버리지(H)    2075
# 328  233160         3         국내파생           TIGER 코스닥150 레버리지    7740
# 336  456680         4         해외주식        TIGER 차이나전기차레버리지(합성)    6250
# 350  494310         2     국내 업종/테마               KODEX 반도체레버리지    7300
# 367  123320         3         국내파생                  TIGER 레버리지   14305
# 385  453820         4         해외주식     KODEX 인도Nifty50레버리지(합성)   18535
# 389  261250         7           기타            KODEX 미국달러선물레버리지   16195
# 423  167860         6           채권            KOSEF 국고채10년레버리지  118390
# 429  304780         3         국내파생            HANARO 200선물레버리지   16135
# 435  438320         4         해외주식     TIGER 차이나항셍테크레버리지(합성 H)    7055
# 488  488080         3         국내파생          TIGER 반도체TOP10레버리지    4375
# 497  196030         4         해외주식          ACE 일본TOPIX레버리지(H)   42950
# 514  243880         2     국내 업종/테마             TIGER 200IT레버리지   24220
# 516  225800         7           기타            KOSEF 미국달러선물레버리지   15360
# 550  252400         3         국내파생              RISE 200선물레버리지   13290
# 569  461910         4         해외주식      PLUS 미국테크TOP10레버리지(합성)   30235
# 592  451670         6           채권          RISE 국채30년레버리지(합성)   26760
# 625  306950         3         국내파생            KODEX KRX300레버리지   11510
# 659  261110         7           기타            TIGER 미국달러선물레버리지   16250
# 680  225050         4         해외주식       TIGER 유로스탁스레버리지(합성 H)   11265
# 689  225060         4         해외주식   TIGER 이머징마켓MSCI레버리지(합성 H)    8000
# 722  225130         4         해외주식         ACE 골드선물 레버리지(합성 H)   26095
# 730  267490         6           채권     RISE 미국장기국채선물레버리지(합성 H)    5960
# 735  152500         3         국내파생                    ACE 레버리지    5885
# 775  253150         3         국내파생              PLUS 200선물레버리지   26850
# 776  219900         4         해외주식      ACE 중국본토CSI300레버리지(합성)    3325
# 782  253250         3         국내파생             KOSEF 200선물레버리지   13140
# 875  486780         3         국내파생        HANARO 200선물레버리지1.5X   11010
# 887  486790         3         국내파생     HANARO 코스닥150선물레버리지1.5X   10490
# 893  371130         4         해외주식    ACE 베트남VN30선물블룸버그레버리지(H)   11525
# 910  291630         3         국내파생          KOSEF 코스닥150선물레버리지    3425
# 915  243890         2     국내 업종/테마          TIGER 200에너지화학레버리지    3395
# 925  306530         3         국내파생         HANARO 코스닥150선물레버리지    6900
# 926  412560         2     국내 업종/테마              TIGER BBIG레버리지    2045
#
#      RiseFall  Change  ChangeRate       NAV  EarningRate    Volume  Amount  \
# 12          2     150        1.05   14556.0      -8.1600  12598127  183165
# 20          2     150        2.21    6958.0     -10.7308  26094864  181223
# 131         2    1115        4.81   24422.0      23.3117    104967    2542
# 140         2     355        2.81   13050.0      28.2233     73851     958
# 153         5     -10       -0.68    1474.0     -36.1905   5877724    8632
# 223         2     815        3.10   27237.0      47.9055     44501    1203
# 248         2      55        0.28   20085.0      70.0858      4754      93
# 268         2    1465        5.13   29984.0      63.1503     44148    1318
# 279         5    -125       -1.97    6212.0     -16.7869     96203     599
# 290         3       0        0.00    1584.0     -35.8860    663745    1049
# 291         2     120        1.09   11075.0      -8.2427     41749     463
# 299         2     530        1.10   48996.0      20.1393      3805     185
# 303         2      85        0.18   46852.0       6.1591       972      45
# 304         2     205        2.69    7827.0     -10.5696     19045     150
# 322         5      -5       -0.24    2078.0      41.7859    190492     396
# 328         2     155        2.04    7755.0     -10.3428    365144    2833
# 336         5     -20       -0.32    6300.0      78.8873     23099     144
# 350         2     275        3.91    7338.0          NaN     33072     243
# 367         2     165        1.17   14292.0      -8.1222     71903    1030
# 385         5     -65       -0.35   18671.0       5.8020      2756      50
# 389         3       0        0.00   16206.0      16.0931     18660     301
# 423         5    -610       -0.51  118404.0       3.2896        86      10
# 429         2     200        1.26   16103.0      -8.2350      2131      34
# 435         2       5        0.07    7030.0      60.4095     60827     432
# 488         2     145        3.43    4391.0     -19.6582    242405    1072
# 497         2    1070        2.55   42963.0      17.6900       176       7
# 514         2     620        2.63   24212.0     -24.6729      2131      51
# 516         5     -35       -0.23   15409.0      15.7083       167       2
# 550         2     145        1.10   13291.0      -8.3014      4199      56
# 569         2    1080        3.70   30434.0      63.0592      2997      90
# 592         5    -130       -0.48   26708.0      14.0373      4313     115
# 625         2     140        1.23   11578.0      -8.4910       130       1
# 659         5     -15       -0.09   16302.0      15.7651       733      11
# 680         2     180        1.62   11286.0       4.3294       211       2
# 689         3       0        0.00    8111.0       6.1712        25       0
# 722         2     330        1.28   26133.0      11.2478      7023     183
# 730         5     -75       -1.24    5957.0     -13.1030      5226      31
# 735         2      50        0.86    5889.0      -7.6741      7654      45
# 775         2     335        1.26   26796.0      -8.1732        79       2
# 776         5     -30       -0.89    3389.0      65.2709      2677       8
# 782         2     140        1.08   13158.0      -8.2569      7870     103
# 875         2     175        1.62   11034.0      -5.8645       117       1
# 887         2     195        1.89   10567.0      -7.5438       253       2
# 893         2      70        0.61   11445.0       1.6415       120       1
# 910         2      80        2.39    3425.0     -10.5615     37291     127
# 915         2     110        3.35    3419.0     -29.0497     32863     112
# 925         2     160        2.37    6886.0     -10.4914      4350      30
# 926         2      35        1.74    2025.0       1.3104       207       0
#
#      MarCap   Brand    인버스  레버리지     헤지
# 12    24157   KODEX  False  True  False
# 20    17907   KODEX  False  True  False
# 131    2268   TIGER  False  True  False
# 140    2156   KODEX  False  True  False
# 153    1959   KODEX  False  True  False
# 223    1166   TIGER  False  True  False
# 248    1025   TIGER  False  True  False
# 268     900     ACE  False  True  False
# 279     833     ACE  False  True  False
# 290     743   TIGER  False  True  False
# 291     743   TIGER  False  True  False
# 299     713   TIGER  False  True  False
# 303     697   TIGER  False  True  False
# 304     684    RISE  False  True  False
# 322     583   KODEX  False  True   True
# 328     565   TIGER  False  True  False
# 336     525   TIGER  False  True  False
# 350     489   KODEX  False  True  False
# 367     429   TIGER  False  True  False
# 385     399   KODEX  False  True  False
# 389     384   KODEX  False  True  False
# 423     320   KOSEF  False  True  False
# 429     307  HANARO  False  True  False
# 435     292   TIGER  False  True  False
# 488     221   TIGER  False  True  False
# 497     215     ACE  False  True   True
# 514     188   TIGER  False  True  False
# 516     187   KOSEF  False  True  False
# 550     159    RISE  False  True  False
# 569     151    PLUS  False  True  False
# 592     134    RISE  False  True  False
# 625     115   KODEX  False  True  False
# 659      98   TIGER  False  True  False
# 680      90   TIGER  False  True  False
# 689      88   TIGER  False  True  False
# 722      78     ACE  False  True  False
# 730      77    RISE  False  True  False
# 735      77     ACE  False  True  False
# 775      67    PLUS  False  True  False
# 776      67     ACE  False  True  False
# 782      66   KOSEF  False  True  False
# 875      42  HANARO  False  True  False
# 887      38  HANARO  False  True  False
# 893      35     ACE  False  True   True
# 910      26   KOSEF  False  True  False
# 915      25   TIGER  False  True  False
# 925      17  HANARO  False  True  False
# 926      16   TIGER  False  True  False

# %%
# 날짜는 파이썬 표준라이브러리 datetime 사용
import datetime
# 오늘 날짜 구하기
today = datetime.datetime.today()
today = today.strftime('%Y-%m-%d')
today
# Out:
# '2024-12-13'

# %%
file_name = f'new_etf_{today}.csv'
file_name
# Out:
# 'new_etf_2024-12-13.csv'

# %%
df_etfs.to_csv(file_name, index=False)
